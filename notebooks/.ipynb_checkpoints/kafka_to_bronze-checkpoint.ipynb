# %%
from confluent_kafka import Consumer, KafkaError
import psycopg2
import json

# Configuration du consommateur Kafka
conf = {
    'bootstrap.servers': 'host.docker.internal:9092',  # Adresse de votre broker Kafka
    'group.id': 'my_group',                           # Identifiant du groupe de consommateurs
    'auto.offset.reset': 'earliest'                   # Lire depuis le début si aucun offset n'existe
}

# Création du consommateur Kafka
consumer = Consumer(conf)

# Connexion à PostgreSQL
pg_conf = {
    'host': 'postgres',  # ou 'localhost' si vous ne l'exécutez pas dans Docker
    'port': '5432',
    'database': 'twitterdb',
    'user': 'fadi',
    'password': 'fadi'
}

try:
    # Établir une connexion à PostgreSQL
    print("Connexion à PostgreSQL...")
    conn = psycopg2.connect(**pg_conf)
    cursor = conn.cursor()

    # Créer une table pour les données brutes (Bronze)
    print("Création de la table bronze_mastodon si elle n'existe pas déjà...")
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS bronze_mastodon (
        id BIGINT PRIMARY KEY,
        content TEXT,
        username TEXT,
        reblogs_count BIGINT,
        favourites_count BIGINT,
        replies_count BIGINT,
        language TEXT,
        url TEXT,
        media_url TEXT,
        media_preview_url TEXT,
        hashtags TEXT,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    """)
    conn.commit()
    print("Table bronze_mastodon prête.")

    # Souscription au topic Kafka
    consumer.subscribe(['mastodon_stream'])
    print("Souscription au topic 'mastodon_stream' réussie.")

    while True:
        # Poll pour les nouveaux contenus
        print("Polling Kafka pour de nouveaux contenus...")
        msg = consumer.poll(1.0)  # Attendre jusqu'à 1 seconde pour un contenu

        if msg is None:
            continue
        if msg.error():
            print(f"Erreur Kafka: {msg.error()}")
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(f"Erreur irrécupérable: {msg.error()}")
                break

        try:
            # Décoder le contenu reçu de Kafka
            content_value = msg.value().decode('utf-8')
            print(f"Contenu reçu de Kafka : {content_value}")
            content_json = json.loads(content_value)

            # Récupérer les données importantes du contenu
            content_id = content_json.get('id')
            content_created_at = content_json.get('created_at')
            content = content_json.get('content')
            username = content_json.get('username')
            reblogs_count = content_json.get('reblogs_count', 0)
            favourites_count = content_json.get('favourites_count', 0)
            replies_count = content_json.get('replies_count', 0)
            language = content_json.get('language')
            url = content_json.get('url')

            # Récupérer les médias s'ils sont présents
            media_url = None
            media_preview_url = None
            if 'media_attachments' in content_json and content_json['media_attachments']:
                media_url = content_json['media_attachments'][0].get('url')
                media_preview_url = content_json['media_attachments'][0].get('preview_url')

            # Récupérer les hashtags s'ils sont présents (sous forme de chaîne)
            hashtags = content_json.get('hashtags', '')  # On récupère directement comme chaîne

            # Afficher le contenu reçu
            print(f"ID: {content_id}, Content: {content}, Hashtags: {hashtags}")

            # Vérifier si l'identifiant existe déjà dans la base de données
            cursor.execute("""
            SELECT 1 FROM bronze_mastodon WHERE id = %s
            """, (content_id,))
            exists = cursor.fetchone()

            if not exists:
                # Insérer le contenu dans la table bronze
                cursor.execute("""
                INSERT INTO bronze_mastodon (id, created_at, content, username, reblogs_count, favourites_count, replies_count, language, url, media_url, media_preview_url, hashtags) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
                """, (content_id, content_created_at, content, username, reblogs_count, favourites_count, replies_count, language, url, media_url, media_preview_url, hashtags))
                conn.commit()
                print(f"Contenu inséré dans la base de données : {content}")
            else:
                # Mettre à jour les colonnes counts et autres informations si le contenu existe déjà
                cursor.execute("""
                UPDATE bronze_mastodon 
                SET created_at = %s, content = %s, username = %s, reblogs_count = %s, favourites_count = %s, replies_count = %s, language = %s, url = %s, media_url = %s, media_preview_url = %s, hashtags = %s
                WHERE id = %s;
                """, (content_created_at, content, username, reblogs_count, favourites_count, replies_count, language, url, media_url, media_preview_url, hashtags, content_id))
                conn.commit()
                print(f"Contenu mis à jour dans la base de données : {content}")

        except json.JSONDecodeError as e:
            print(f"Erreur lors du décodage du contenu JSON : {e}")
        except Exception as e:
            print(f"Erreur inattendue : {e}")

except KeyboardInterrupt:
    print("Interruption par l'utilisateur.")

except Exception as e:
    print(f"Erreur générale : {e}")

finally:
    # Fermer les connexions
    print("Fermeture des connexions...")
    consumer.close()
    if cursor:
        cursor.close()
    if conn:
        conn.close()
    print("Connexions fermées.")
# Out:
# Connexion à PostgreSQL...
# Création de la table bronze_mastodon si elle n'existe pas déjà...
# Table bronze_mastodon prête.
# Souscription au topic 'mastodon_stream' réussie.
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262442482498231, "created_at": "2024-10-06 20:48:38.546000+00:00", "content": "<p>Absolutely amazing historical fiction about Yayomanekuh (Yamabe Yasunosuke) and Bronis\u0142aw Pi\u0142sudski whose paths crossed several times. Kawagoe did a fantastic job bringing this story (back) to life, raising questions about the concepts of, i.a., identity and home(land). <a href=\"https://mastodon.social/tags/%E8%AA%AD%E4%BA%86\" class=\"mention hashtag\" rel=\"tag\">#<span>\u8aad\u4e86</span></a></p>", "username": "kojinmanus", "replies_count": 2, "reblogs_count": 98, "favourites_count": 99, "hashtags": "\u8aad\u4e86", "language": "en", "url": "https://mastodon.social/@kojinmanus/113262442482498231", "media_attachments": []}
# ID: 113262442482498231, Content: <p>Absolutely amazing historical fiction about Yayomanekuh (Yamabe Yasunosuke) and Bronisław Piłsudski whose paths crossed several times. Kawagoe did a fantastic job bringing this story (back) to life, raising questions about the concepts of, i.a., identity and home(land). <a href="https://mastodon.social/tags/%E8%AA%AD%E4%BA%86" class="mention hashtag" rel="tag">#<span>読了</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p>Absolutely amazing historical fiction about Yayomanekuh (Yamabe Yasunosuke) and Bronisław Piłsudski whose paths crossed several times. Kawagoe did a fantastic job bringing this story (back) to life, raising questions about the concepts of, i.a., identity and home(land). <a href="https://mastodon.social/tags/%E8%AA%AD%E4%BA%86" class="mention hashtag" rel="tag">#<span>読了</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262442501312367, "created_at": "2024-10-06 20:48:37+00:00", "content": "<p>Tall order for the <a href=\"https://techhub.social/tags/WashingtonSpirit\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>WashingtonSpirit</span></a> tonight. So many starters out. :blobugh: <br><a href=\"https://techhub.social/tags/NWSL\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>NWSL</span></a> <a href=\"https://techhub.social/tags/WoSo\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>WoSo</span></a> <a href=\"https://techhub.social/tags/MastodonFC\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>MastodonFC</span></a></p>", "username": "todd", "replies_count": 53, "reblogs_count": 50, "favourites_count": 45, "hashtags": "washingtonspirit, nwsl, woso, mastodonfc", "language": "en", "url": "https://techhub.social/@todd/113262442420938376", "media_attachments": []}
# ID: 113262442501312367, Content: <p>Tall order for the <a href="https://techhub.social/tags/WashingtonSpirit" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WashingtonSpirit</span></a> tonight. So many starters out. :blobugh: <br><a href="https://techhub.social/tags/NWSL" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>NWSL</span></a> <a href="https://techhub.social/tags/WoSo" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WoSo</span></a> <a href="https://techhub.social/tags/MastodonFC" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MastodonFC</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p>Tall order for the <a href="https://techhub.social/tags/WashingtonSpirit" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WashingtonSpirit</span></a> tonight. So many starters out. :blobugh: <br><a href="https://techhub.social/tags/NWSL" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>NWSL</span></a> <a href="https://techhub.social/tags/WoSo" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WoSo</span></a> <a href="https://techhub.social/tags/MastodonFC" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MastodonFC</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262442517720352, "created_at": "2024-10-06 20:33:26+00:00", "content": "<p>\uc5f0\ub0a8\ub3d9 \uc0cc\ub4dc\uc704\uce58 \ub3c4\ub451 \u3137\u3137\u3137<br>.<br>.<br>\ub178\ud2b8\ubd81\uc740 \ub194\ub450\uace0...</p>", "username": "kekewo_net", "replies_count": 80, "reblogs_count": 89, "favourites_count": 54, "hashtags": "", "language": "ko", "url": "https://www.threads.net/@kekewo_net/post/DAy9Z0BujHb", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/442/423/959/610/original/a4a3777fe623e585.mp4", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/442/423/959/610/small/a4a3777fe623e585.png", "description": null}]}
# ID: 113262442517720352, Content: <p>연남동 샌드위치 도둑 ㄷㄷㄷ<br>.<br>.<br>노트북은 놔두고...</p>, Hashtags:
# Contenu inséré dans la base de données : <p>연남동 샌드위치 도둑 ㄷㄷㄷ<br>.<br>.<br>노트북은 놔두고...</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262442600828764, "created_at": "2024-10-06 20:48:40.353000+00:00", "content": "<p><a href=\"https://mastodon.social/tags/EnVideo\" class=\"mention hashtag\" rel=\"tag\">#<span>EnVideo</span></a>\ud83d\udcf9|  Zulia | M\u00e1s de 6 mil Familias son beneficiadas con jornada de venta de alimentos a precios asequibles</p><p><a href=\"https://mastodon.social/tags/06Oct\" class=\"mention hashtag\" rel=\"tag\">#<span>06Oct</span></a></p><p><a href=\"https://dai.ly/x96vrd2\" target=\"_blank\" rel=\"nofollow noopener noreferrer\" translate=\"no\"><span class=\"invisible\">https://</span><span class=\"\">dai.ly/x96vrd2</span><span class=\"invisible\"></span></a></p>", "username": "VTVCANAL8", "replies_count": 75, "reblogs_count": 75, "favourites_count": 98, "hashtags": "envideo, 06OCT", "language": "es", "url": "https://mastodon.social/@VTVCANAL8/113262442600828764", "media_attachments": []}
# ID: 113262442600828764, Content: <p><a href="https://mastodon.social/tags/EnVideo" class="mention hashtag" rel="tag">#<span>EnVideo</span></a>📹|  Zulia | Más de 6 mil Familias son beneficiadas con jornada de venta de alimentos a precios asequibles</p><p><a href="https://mastodon.social/tags/06Oct" class="mention hashtag" rel="tag">#<span>06Oct</span></a></p><p><a href="https://dai.ly/x96vrd2" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">dai.ly/x96vrd2</span><span class="invisible"></span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <
></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443092149373, "created_at": "2024-10-06 20:33:32+00:00", "content": "<p>OMG that Ravens game was so good right to the last play.</p>", "username": "karolik", "replies_count": 31, "reblogs_count": 40, "favourites_count": 79, "hashtags": "", "language": "en", "url": "https://www.threads.net/@karolik/post/DAy9bwKvpKC", "media_attachments": []}
# ID: 113262443092149373, Content: <p>OMG that Ravens game was so good right to the last play.</p>, Hashtags:
# Contenu inséré dans la base de données : <p>OMG that Ravens game was so good right to the last play.</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443104547040, "created_at": "2024-10-06 20:33:34+00:00", "content": "<p>I think it was lost.</p>", "username": "matt_rosser", "replies_count": 36, "reblogs_count": 63, "favourites_count": 53, "hashtags": "", "language": "en", "url": "https://www.threads.net/@matt_rosser/post/DAy9b_xuWtP", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/069/039/179/original/f086a1c1174daa3a.jpg", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/069/039/179/small/f086a1c1174daa3a.jpg", "description": "Photo by Matt Rosser on October 06, 2024. May be an image of speaker, telescope, flashlight, projector, binoculars and camera."}]}
# ID: 113262443104547040, Content: <p>I think it was lost.</p>, Hashtags:
# Contenu inséré dans la base de données : <p>I think it was lost.</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443117353673, "created_at": "2024-10-06 20:33:31+00:00", "content": "<p>Ravens win in OT and everyone watching needs a chiropractor</p>", "username": "ami.l.berger", "replies_count": 58, "reblogs_count": 67, "favourites_count": 19, "hashtags": "", "language": "en", "url": "https://www.threads.net/@ami.l.berger/post/DAy9bqwSHzN", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/079/111/250/original/cb0ce96725e82506.mp4", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/079/111/250/small/cb0ce96725e82506.png", "description": null}]}
# ID: 113262443117353673, Content: <p>Ravens win in OT and everyone watching needs a chiropractor</p>, Hashtags:
# Contenu inséré dans la base de données : <p>Ravens win in OT and everyone watching needs a chiropractor</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443135131053, "created_at": "2024-10-06 20:48:45+00:00", "content": "<p>Apura\u00e7\u00e3o mal come\u00e7ou e eu j\u00e1 t\u00f4 odiando Piracicaba ainda mais.<br>Caipirada fdp! \ud83e\udd2c\ud83e\udd2c\ud83e\udd2c</p>", "username": "Minduin", "replies_count": 16, "reblogs_count": 53, "favourites_count": 97, "hashtags": "", "language": "pt", "url": "https://ursal.zone/@Minduin/113262442937954606", "media_attachments": []}
# ID: 113262443135131053, Content: <p>Apuração mal começou e eu já tô odiando Piracicaba ainda mais.<br>Caipirada fdp! 🤬🤬🤬</p>, Hashtags:
# Contenu inséré dans la base de données : <p>Apuração mal começou e eu já tô odiando Piracicaba ainda mais.<br>Caipirada fdp! 🤬🤬🤬</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443144489603, "created_at": "2024-10-06 20:33:33+00:00", "content": "<p>Lawyer and Parrotlegals.</p>", "username": "theleftistlawyer", "replies_count": 48, "reblogs_count": 39, "favourites_count": 75, "hashtags": "", "language": "en", "url": "https://www.threads.net/@theleftistlawyer/post/DAy9b5Kv5_W", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/442/987/555/158/original/8984c01b6956931d.jpeg", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/442/987/555/158/small/8984c01b6956931d.jpeg", "description": "Photo by Sheryl Weikal on October 06, 2024. May be an image of 1 person, makeup, parrot, lorikeet, macaw and budgie."}, {"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/024/657/274/original/f0eec6f24b2a081d.jpeg", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/024/657/274/small/f0eec6f24b2a081d.jpeg", "description": "Photo by Sheryl Weikal on October 06, 2024. May be a selfie of 1 person, bangs and makeup."}, {"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/062/356/256/original/4c74efa3ce524452.jpeg", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/062/356/256/small/4c74efa3ce524452.jpeg", "description": "Photo by Sheryl Weikal on October 06, 2024. May be an image of 1 person, parrot, macaw and budgie."}]}
# ID: 113262443144489603, Content: <p>Lawyer and Parrotlegals.</p>, Hashtags:
# Contenu inséré dans la base de données : <p>Lawyer and Parrotlegals.</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443148285123, "created_at": "2024-10-06 20:48:48+00:00", "content": "<p>\u7acb\u61b2\u516c\u7d04 \u4e2d\u4f4e\u6240\u5f97\u8005\u306b\u6d88\u8cbb\u7a0e\u9084\u4ed8<br><a href=\"https://news.yahoo.co.jp/pickup/6515785?source=rss\" rel=\"nofollow noopener noreferrer\" target=\"_blank\"><span class=\"invisible\">https://</span><span class=\"ellipsis\">news.yahoo.co.jp/pickup/651578</span><span class=\"invisible\">5?source=rss</span></a></p>", "username": "YahooNewsBot", "replies_count": 59, "reblogs_count": 73, "favourites_count": 45, "hashtags": "", "language": "ja", "url": "https://fedibird.com/@YahooNewsBot/113262443119337756", "media_attachments": []}
# ID: 113262443148285123, Content: <p>立憲公約 中低所得者に消費税還付<br><a href="https://news.yahoo.co.jp/pickup/6515785?source=rss" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">news.yahoo.co.jp/pickup/651578</span><span class="invisible">5?source=rss</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p>立憲公約 中低所得者に消費税還付<br><a href="https://news.yahoo.co.jp/pickup/6515785?source=rss" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">news.yahoo.co.jp/pickup/651578</span><span class="invisible">5?source=rss</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443165709349, "created_at": "2024-10-06 20:33:36+00:00", "content": "<p>If you\u2019re not in DBA, wyd\u2026??</p>", "username": "lessfacemorespace", "replies_count": 56, "reblogs_count": 85, "favourites_count": 28, "hashtags": "", "language": "en", "url": "https://www.threads.net/@lessfacemorespace/post/DAy9cO3T1b9", "media_attachments": []}
# ID: 113262443165709349, Content: <p>If you’re not in DBA, wyd…??</p>, Hashtags:
# Contenu inséré dans la base de données : <p>If you’re not in DBA, wyd…??</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443194548196, "created_at": "2024-10-06 20:48:48+00:00", "content": "<p>I\u2019m privately posting my inktober microfictions for now. Should i post it publicly here too ? In French (in the language they\u2019re written) or translated in English ? If any of the people following me express an interest, I\u2019ll do it (though I doubt I\u2019ll have the motivation for a whole month)</p>", "username": "ewjoachim", "replies_count": 69, "reblogs_count": 77, "favourites_count": 18, "hashtags": "", "language": "fr", "url": "https://fosstodon.org/@ewjoachim/113262443157951616", "media_attachments": []}
# ID: 113262443194548196, Content: <p>I’m privately posting my inktober microfictions for now. Should i post it publicly here too ? In French (in the language they’re written) or translated in English ? If any of the people following me express an interest, I’ll do it (though I doubt I’ll have the motivation for a whole month)</p>, Hashtags:
# Contenu inséré dans la base de données : <p>I’m privately posting my inktober microfictions for now. Should i post it publicly here too ? In French (in the language they’re written) or translated in English ? If any of the people following me express an interest, I’ll do it (though I doubt I’ll have the motivation for a whole month)</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443207129982, "created_at": "2024-10-06 20:48:49.602000+00:00", "content": "<p>6</p>", "username": "bobeslaw", "replies_count": 75, "reblogs_count": 57, "favourites_count": 39, "hashtags": "", "language": "en", "url": "https://mastodon.social/@bobeslaw/113262443207129982", "media_attachments": []}
# ID: 113262443207129982, Content: <p>6</p>, Hashtags:
# Contenu inséré dans la base de données : <p>6</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443222952835, "created_at": "2024-10-06 20:48:48.159000+00:00", "content": "<p><a href=\"https://federation.network/tags/feditipp\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">
" rel=\"nofollow noopener noreferrer\" translate=\"no\" target=\"_blank\"><span class=\"invisible\">https://</span><span class=\"ellipsis\">pixelfed.social/p/bestacy/7486</span><span class=\"invisible\">42836970986387</span></a></p>", "username": "absolutely", "replies_count": 70, "reblogs_count": 88, "favourites_count": 66, "hashtags": "", "language": "ru", "url": "https://mastodon.ml/@absolutely/113262443227388588", "media_attachments": []}
# ID: 113262443256507504, Content: <p>Почитала тут ваши новости… изобрели какую-то штуку, чтобы связать тг и мастодон офигеть… ничего, конечно, делать пока не буду, но ого что творят </p><p>В пиксельфеде еще пост про новую работу оставила <a href="https://pixelfed.social/p/bestacy/748642836970986387" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">pixelfed.social/p/bestacy/7486</span><span class="invisible">42836970986387</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p>Почитала тут ваши новости… изобрели какую-то штуку, чтобы связать тг и мастодон офигеть… ничего, конечно, делать пока не буду, но ого что творят </p><p>В пиксельфеде еще пост про новую работу оставила <a href="https://pixelfed.social/p/bestacy/748642836970986387" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">pixelfed.social/p/bestacy/7486</span><span class="invisible">42836970986387</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443242519817, "created_at": "2024-10-06 20:46:43+00:00", "content": "<p>The Giants may never recover from the boat pic</p>", "username": "barstoolsports", "replies_count": 31, "reblogs_count": 52, "favourites_count": 71, "hashtags": "", "language": "en", "url": "https://twitter.com/barstoolsports/status/1843030147890561483", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/098/929/863/original/4c4bc514d96fb8ec.mp4", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/098/929/863/small/4c4bc514d96fb8ec.png", "description": null}]}
# ID: 113262443242519817, Content: <p>The Giants may never recover from the boat pic</p>, Hashtags:
# Contenu inséré dans la base de données : <p>The Giants may never recover from the boat pic</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443312987896, "created_at": "2024-10-06 20:48:51.223000+00:00", "content": "<p><a href=\"https://mastodon.social/tags/AppleII\" class=\"mention hashtag\" rel=\"tag\">#<span>AppleII</span></a> <a href=\"https://mastodon.social/tags/terminal\" class=\"mention hashtag\" rel=\"tag\">#<span>terminal</span></a> <a href=\"https://mastodon.social/tags/emulation\" class=\"mention hashtag\" rel=\"tag\">#<span>emulation</span></a></p>", "username": "mmphosis", "replies_count": 85, "reblogs_count": 99, "favourites_count": 15, "hashtags": "appleii, terminal, emulation", "language": "en", "url": "https://mastodon.social/@mmphosis/113262443312987896", "media_attachments": [{"url": "https://files.mastodon.social/media_attachments/files/113/262/440/185/600/447/original/95c7fad1589d3ca9.png", "preview_url": "https://files.mastodon.social/media_attachments/files/113/262/440/185/600/447/small/95c7fad1589d3ca9.png", "description": "Apple II emulation in the Terminal using KEGS."}]}
# ID: 113262443312987896, Content: <p><a href="https://mastodon.social/tags/AppleII" class="mention hashtag" rel="tag">#<span>AppleII</span></a> <a href="https://mastodon.social/tags/terminal" class="mention hashtag" rel="tag">#<span>terminal</span></a> <a href="https://mastodon.social/tags/emulation" class="mention hashtag" rel="tag">#<span>emulation</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p><a href="https://mastodon.social/tags/AppleII" class="mention hashtag" rel="tag">#<span>AppleII</span></a> <a href="https://mastodon.social/tags/terminal" class="mention hashtag" rel="tag">#<span>terminal</span></a> <a href="https://mastodon.social/tags/emulation" class="mention hashtag" rel="tag">#<span>emulation</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443317461477, "created_at": "2024-10-06 20:48:49+00:00", "content": "<p>Shedding light on alcohol's long shadow<br>L: <a href=\"https://news.harvard.edu/gazette/story/2024/10/shedding-light-on-alcohols-long-shadow/\" rel=\"nofollow noopener noreferrer\" translate=\"no\" target=\"_blank\"><span class=\"invisible\">https://</span><span class=\"ellipsis\
p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443396321753, "created_at": "2024-10-06 20:47:39+00:00", "content": "<p>LUKA SUCIC WITH AN ABSOLUTE WORLDIE TO TIE IT FOR REAL SOCIEDAD VS. ATLETICO MADRID \ud83e\udd2f\ud83e\udd2f\ud83e\udd2f</p><p>TAKE A BOW \ud83d\udc4f</p>", "username": "ESPNFC", "replies_count": 62, "reblogs_count": 57, "favourites_count": 35, "hashtags": "", "language": "en", "url": "https://twitter.com/ESPNFC/status/1843030380363862480", "media_attachments": [{"url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/175/956/517/original/c827568966767fac.mp4", "preview_url": "https://files.mastodon.social/cache/media_attachments/files/113/262/443/175/956/517/small/c827568966767fac.png", "description": null}]}
# ID: 113262443396321753, Content: <p>LUKA SUCIC WITH AN ABSOLUTE WORLDIE TO TIE IT FOR REAL SOCIEDAD VS. ATLETICO MADRID 🤯🤯🤯</p><p>TAKE A BOW 👏</p>, Hashtags:
# Contenu inséré dans la base de données : <p>LUKA SUCIC WITH AN ABSOLUTE WORLDIE TO TIE IT FOR REAL SOCIEDAD VS. ATLETICO MADRID 🤯🤯🤯</p><p>TAKE A BOW 👏</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443504771667, "created_at": "2024-10-06 20:48:53+00:00", "content": "<p>Thanks for attending! We will start building the public API next time (I hope!), so follow me on YouTube if you aren't already:</p><p><a href=\"https://www.youtube.com/@seancribbs\" rel=\"nofollow noopener noreferrer\" translate=\"no\" target=\"_blank\"><span class=\"invisible\">https://www.</span><span class=\"\">youtube.com/@seancribbs</span><span class=\"invisible\"></span></a></p><p>See you next week!</p><p><a href=\"https://hachyderm.io/tags/RustLang\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>RustLang</span></a> <a href=\"https://hachyderm.io/tags/Erlang\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>Erlang</span></a> <a href=\"https://hachyderm.io/tags/Databases\" class=\"mention hashtag\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">#<span>Databases</span></a></p>", "username": "seancribbs", "replies_count": 28, "reblogs_count": 16, "favourites_count": 41, "hashtags": "rustlang, erlang, databases", "language": "en", "url": "https://hachyderm.io/@seancribbs/113262443458763636", "media_attachments": []}
# ID: 113262443504771667, Content: <p>Thanks for attending! We will start building the public API next time (I hope!), so follow me on YouTube if you aren't already:</p><p><a href="https://www.youtube.com/@seancribbs" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">youtube.com/@seancribbs</span><span class="invisible"></span></a></p><p>See you next week!</p><p><a href="https://hachyderm.io/tags/RustLang" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>RustLang</span></a> <a href="https://hachyderm.io/tags/Erlang" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Erlang</span></a> <a href="https://hachyderm.io/tags/Databases" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Databases</span></a></p>, Hashtags:
# Contenu inséré dans la base de données : <p>Thanks for attending! We will start building the public API next time (I hope!), so follow me on YouTube if you aren't already:</p><p><a href="https://www.youtube.com/@seancribbs" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">youtube.com/@seancribbs</span><span class="invisible"></span></a></p><p>See you next week!</p><p><a href="https://hachyderm.io/tags/RustLang" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>RustLang</span></a> <a href="https://hachyderm.io/tags/Erlang" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Erlang</span></a> <a href="https://hachyderm.io/tags/Databases" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Databases</span></a></p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443463045039, "created_at": "2024-10-06 20:47:26+00:00", "content": "<p>\ud83d\udcfa: CBS</p>", "username": "Seahawks", "replies_count": 15, "reblogs_count": 25, "favourites_count": 29, "hashtags": "", "language": "und", "url": "https://twitter.com/Seahawks/status/1843030325297066390", "media_attachments": []}
# ID: 113262443463045039, Content: <p>📺: CBS</p>, Hashtags:
# Contenu inséré dans la base de données : <p>📺: CBS</p>
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443546222745, "created_at": "2024-10-06 20:48:54.778000+00:00", "content": "", "username": "LorettaNash", "replies_count": 77, "reblogs_count": 84, "favourites_count": 15, "hashtags": "", "language": "en", "url": "https://mastodon.social/@LorettaNash/113262443546222745", "media_attachments": [{"url": "https://files.mastodon.social/media_attachments/files/113/262/443/266/629/378/original/c5049331c5770521.jpg", "preview_url": "https://files.mastodon.social/media_attachments/files/113/262/443/266/629/378/small/c5049331c5770521.jpg", "description": null}]}
# ID: 113262443546222745, Content: , Hashtags:
# Contenu inséré dans la base de données :
# Polling Kafka pour de nouveaux contenus...
# Contenu reçu de Kafka : {"id": 113262443538763916, "created_at": "2024-10-06 20:48:35+00:00", "content": "<p><span class=\"h-card\" translate=\"no\"><a href=\"https://cosocial.ca/@evan\" class=\"u-url mention\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">@<span>evan</span></a></span> <span class=\"h-card\" translate=\"no\"><a href=\"https://mas.to/@Identitywoman\" class=\"u-url mention\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">@<span>Identitywoman</span></a></span> <span class=\"h-card\" translate=\"no\"><a href=\"https://j12t.social/@j12t\" class=\"u-url mention\" rel=\"nofollow noopener noreferrer\" target=\"_blank\">@<span>j12t</span></a></span> Friends, a thought: We had such an overpowering interest in the Open Social Incubator (177 apps for 8 slots) that we are thinking about creating a forum space (prob. Discourse) for people building community in open social networks. We want this to be resonant and mutually supporting with efforts like yours.</p><p>Do you see any dangers with this approach, or is there redundancy with anything you're aware of?</p>", "username": "ntnsndr", "replies_count": 44, "reblogs_count": 37, "favourites_count": 35, "hashtags": "", "language": "en", "url": "https://social.coop/@ntnsndr/113262442294683640", "media_attachments": []}
# ID: 113262443538763916, Content: <p><span class="h-card" translate="no"><a href="https://cosocial.ca/@evan" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>evan</span></a></span> <span class="h-card" translate="no"><a href="https://mas.to/@Identitywoman" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>Identitywoman</span></a></span> <span class="h-card" translate="no"><a href="https://j12t.social/@j12t" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>j12t</span></a></span> Friends, a thought: We had such an overpowering interest in the Open Social Incubator (177 apps for 8 slots) that we are thinking about creating a forum space (prob. Discourse) for people building community in open social networks. We want this to be resonant and mutually supporting with efforts like yours.</p><p>Do you see any dangers with this approach, or is there redundancy with anything you're aware of?</p>, Hashtags:
# Contenu inséré dans la base de données : <p><span class="h-card" translate="no"><a href="https://cosocial.ca/@evan" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>evan</span></a></span> <span class="h-card" translate="no"><a href="https://mas.to/@Identitywoman" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>Identitywoman</span></a></span> <span class="h-card" translate="no"><a href="https://j12t.social/@j12t" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>j12t</span></a></span> Friends, a thought: We had such an overpowering interest in the Open Social Incubator (177 apps for 8 slots) that we are thinking about creating a forum space (prob. Discourse) for people building community in open social networks. We want this to be resonant and mutually supporting with efforts like yours.</p><p>Do you see any dangers with this approach, or is there redundancy with anything you're aware of?</p>
# Polling Kafka pour de nouveaux contenus...
# Interruption par l'utilisateur.
# Fermeture des connexions...
# Connexions fermées.
