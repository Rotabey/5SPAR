# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_timestamp

# Créer une session Spark
spark = SparkSession.builder \
    .appName("CSV to PostgreSQL") \
    .getOrCreate()

# Spécifiez le chemin de votre fichier CSV
csv_file_path = "/tmp/tweets.csv"

# Lire le fichier CSV dans un DataFrame
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Afficher les schémas et les données brutes
print("Schéma du DataFrame:")
df.printSchema()
print("Données brutes:")
df.show()

# Conversion du champ date_time en format Timestamp
df = df.withColumn("timestamp", to_timestamp(col("date_time"), "yyyy-MM-dd HH:mm:ss"))

# Suppression des enregistrements sans texte ou horodatage
df_cleaned = df.filter(col("content").isNotNull())

# Optionnel : Filtrage par langue (par exemple, les tweets en anglais uniquement)
df_cleaned = df_cleaned.filter(col("language") == "en")

# Affichage des données nettoyées
print("Données nettoyées:")
df_cleaned.show()

# Configurer les paramètres de connexion à PostgreSQL
postgres_url = "jdbc:postgresql://postgres:5432/twitterdb"
properties = {
    "user": "fadi",
    "password": "fadi",
    "driver": "org.postgresql.Driver"
}

# Écrire le DataFrame nettoyé dans la table PostgreSQL
df_cleaned.write.jdbc(url=postgres_url, table="X_TWEET", mode="overwrite", properties=properties)

print("Données nettoyées enregistrées dans PostgreSQL avec succès.")
# Out:
# Schéma du DataFrame:
# root
#  |-- author: string (nullable = true)
#  |-- content: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- date_time: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- number_of_likes: string (nullable = true)
#  |-- number_of_shares: string (nullable = true)
#
# Données brutes:
# +--------------------+--------------------+----------------+----------------+-----------+--------+--------+---------+---------------+----------------+
# |              author|             content|         country|       date_time|         id|language|latitude|longitude|number_of_likes|number_of_shares|
# +--------------------+--------------------+----------------+----------------+-----------+--------+--------+---------+---------------+----------------+
# |           katyperry|Is history repeat...|            NULL|12/01/2017 19:52|8.19633E+17|      en|    NULL|     NULL|           7900|            3472|
# |           katyperry|@barackobama Than...|            NULL|11/01/2017 08:38|8.19101E+17|      en|    NULL|     NULL|           3689|            1380|
# |           katyperry|Life goals. https...|            NULL|11/01/2017 02:52|8.19014E+17|      en|    NULL|     NULL|          10341|            2387|
# |           katyperry|Me right now 🙏🏻...|            NULL|11/01/2017 02:44|8.19012E+17|      en|    NULL|     NULL|          10774|            2458|
# |           katyperry|SISTERS ARE DOIN'...|            NULL|10/01/2017 05:22|8.18689E+17|      en|    NULL|     NULL|          17620|            4655|
# |           katyperry|happy 96th gma #f...|            NULL|09/01/2017 01:00|8.18261E+17|      en|    NULL|     NULL|           8242|            2164|
# |           katyperry|       Kyoto, Japan |            NULL|            NULL|       NULL|    NULL|    NULL|     NULL|           NULL|            NULL|
# |1. 5. 17. https:/...|                NULL|06/01/2017 03:57|     8.17218E+17|         tl|    NULL|    NULL|     7171|           1910|            NULL|
# |           katyperry|🇯🇵 @ Sanrio Pur...|            NULL|02/01/2017 09:31|8.15853E+17|      cy|    NULL|     NULL|           7766|            2468|
# |           katyperry|2017 resolution: ...|            NULL|01/01/2017 03:31|  8.154E+17|      en|    NULL|     NULL|          23662|            8430|
# |           katyperry|sisters. https://...|            NULL|27/12/2016 04:04|8.13596E+17|      en|    NULL|     NULL|           9324|            2637|
# |           katyperry|Happy Holidays! S...|            NULL|25/12/2016 20:35|8.13121E+17|      en|    NULL|     NULL|          23205|            7419|
# |           katyperry|Damn, it's hard t...|            NULL|25/12/2016 05:45|8.12897E+17|      en|    NULL|     NULL|          20410|            5042|
# |           katyperry|When my whole fam...|            NULL|24/12/2016 16:26|8.12696E+17|      en|    NULL|     NULL|           8608|            2183|
# |           katyperry|When your holiday...|            NULL|23/12/2016 18:42|8.12368E+17|      en|    NULL|     NULL|           6713|            1948|
# |           katyperry|@shannonwoodward ...|            NULL|23/12/2016 02:22|8.12121E+17|      en|    NULL|     NULL|           2541|             849|
# |           katyperry|This week Santa a...|            NULL|21/12/2016 23:05|8.11709E+17|      en|    NULL|     NULL|           8592|            2305|
# |           katyperry|Love the music th...|            NULL|21/12/2016 22:42|8.11703E+17|      en|    NULL|     NULL|          11266|            3064|
# |           katyperry|For real tho http...|            NULL|16/12/2016 08:24|8.09676E+17|      en|    NULL|     NULL|          12059|            3589|
# |           katyperry|I can't wait to r...|            NULL|07/12/2016 09:03|8.06424E+17|      en|    NULL|     NULL|           8985|            2446|
# +--------------------+--------------------+----------------+----------------+-----------+--------+--------+---------+---------------+----------------+
# only showing top 20 rows
#
# Données nettoyées:
# +---------+--------------------+-------+----------------+-----------+--------+--------+---------+---------------+----------------+---------+
# |   author|             content|country|       date_time|         id|language|latitude|longitude|number_of_likes|number_of_shares|timestamp|
# +---------+--------------------+-------+----------------+-----------+--------+--------+---------+---------------+----------------+---------+
# |katyperry|Is history repeat...|   NULL|12/01/2017 19:52|8.19633E+17|      en|    NULL|     NULL|           7900|            3472|     NULL|
# |katyperry|@barackobama Than...|   NULL|11/01/2017 08:38|8.19101E+17|      en|    NULL|     NULL|           3689|            1380|     NULL|
# |katyperry|Life goals. https...|   NULL|11/01/2017 02:52|8.19014E+17|      en|    NULL|     NULL|          10341|            2387|     NULL|
# |katyperry|Me right now 🙏🏻...|   NULL|11/01/2017 02:44|8.19012E+17|      en|    NULL|     NULL|          10774|            2458|     NULL|
# |katyperry|SISTERS ARE DOIN'...|   NULL|10/01/2017 05:22|8.18689E+17|      en|    NULL|     NULL|          17620|            4655|     NULL|
# |katyperry|happy 96th gma #f...|   NULL|09/01/2017 01:00|8.18261E+17|      en|    NULL|     NULL|           8242|            2164|     NULL|
# |katyperry|2017 resolution: ...|   NULL|01/01/2017 03:31|  8.154E+17|      en|    NULL|     NULL|          23662|            8430|     NULL|
# |katyperry|sisters. https://...|   NULL|27/12/2016 04:04|8.13596E+17|      en|    NULL|     NULL|           9324|            2637|     NULL|
# |katyperry|Happy Holidays! S...|   NULL|25/12/2016 20:35|8.13121E+17|      en|    NULL|     NULL|          23205|            7419|     NULL|
# |katyperry|Damn, it's hard t...|   NULL|25/12/2016 05:45|8.12897E+17|      en|    NULL|     NULL|          20410|            5042|     NULL|
# |katyperry|When my whole fam...|   NULL|24/12/2016 16:26|8.12696E+17|      en|    NULL|     NULL|           8608|            2183|     NULL|
# |katyperry|When your holiday...|   NULL|23/12/2016 18:42|8.12368E+17|      en|    NULL|     NULL|           6713|            1948|     NULL|
# |katyperry|@shannonwoodward ...|   NULL|23/12/2016 02:22|8.12121E+17|      en|    NULL|     NULL|           2541|             849|     NULL|
# |katyperry|This week Santa a...|   NULL|21/12/2016 23:05|8.11709E+17|      en|    NULL|     NULL|           8592|            2305|     NULL|
# |katyperry|Love the music th...|   NULL|21/12/2016 22:42|8.11703E+17|      en|    NULL|     NULL|          11266|            3064|     NULL|
# |katyperry|For real tho http...|   NULL|16/12/2016 08:24|8.09676E+17|      en|    NULL|     NULL|          12059|            3589|     NULL|
# |katyperry|I can't wait to r...|   NULL|07/12/2016 09:03|8.06424E+17|      en|    NULL|     NULL|           8985|            2446|     NULL|
# |katyperry|I wanna adopt him...|   NULL|07/12/2016 02:35|8.06326E+17|      en|    NULL|     NULL|           6745|            1868|     NULL|
# |katyperry|@jessesaintjohn i...|   NULL|06/12/2016 09:56|8.06075E+17|      en|    NULL|     NULL|           2527|             819|     NULL|
# |katyperry|@jessesaintjohn @...|   NULL|06/12/2016 09:54|8.06074E+17|      en|    NULL|     NULL|           2356|             795|     NULL|
# +---------+--------------------+-------+----------------+-----------+--------+--------+---------+---------------+----------------+---------+
# only showing top 20 rows
#
# Données nettoyées enregistrées dans PostgreSQL avec succès.
