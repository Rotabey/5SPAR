# %%
from confluent_kafka import Consumer, KafkaError
import psycopg2
import json

# Configuration du consommateur Kafka
conf = {
    'bootstrap.servers': 'host.docker.internal:9092',  # Adresse de votre broker Kafka
    'group.id': 'my_group',                           # Identifiant du groupe de consommateurs
    'auto.offset.reset': 'earliest'                   # Lire depuis le début si aucun offset n'existe
}

# Création du consommateur Kafka
consumer = Consumer(conf)

# Connexion à PostgreSQL
pg_conf = {
    'host': 'postgres',  # ou 'localhost' si vous ne l'exécutez pas dans Docker
    'port': '5432',
    'database': 'twitterdb',
    'user': 'fadi',
    'password': 'fadi'
}

try:
    # Établir une connexion à PostgreSQL
    print("Connexion à PostgreSQL...")
    conn = psycopg2.connect(**pg_conf)
    cursor = conn.cursor()

    # Créer une table pour les données brutes (Bronze)
    print("Création de la table bronze_mastodon si elle n'existe pas déjà...")
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS bronze_mastodon (
        id BIGINT PRIMARY KEY,
        content TEXT,
        username TEXT,
        reblogs_count BIGINT,
        favourites_count BIGINT,
        replies_count BIGINT,
        language TEXT,
        url TEXT,
        media_url TEXT,
        media_preview_url TEXT,
        hashtags TEXT,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
    """)
    conn.commit()
    print("Table bronze_mastodon prête.")

    # Souscription au topic Kafka
    consumer.subscribe(['mastodon_stream'])
    print("Souscription au topic 'mastodon_stream' réussie.")

    while True:
        # Poll pour les nouveaux contenus
        print("Polling Kafka pour de nouveaux contenus...")
        msg = consumer.poll(1.0)  # Attendre jusqu'à 1 seconde pour un contenu

        if msg is None:
            continue
        if msg.error():
            print(f"Erreur Kafka: {msg.error()}")
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(f"Erreur irrécupérable: {msg.error()}")
                break

        try:
            # Décoder le contenu reçu de Kafka
            content_value = msg.value().decode('utf-8')
            content_json = json.loads(content_value)

            # Récupérer les hashtags s'ils sont présents
            hashtags = content_json.get('hashtags', [])
            if isinstance(hashtags, list):
                hashtags_str = ', '.join(hashtags)  # Convertir la liste de hashtags en chaîne de texte
                print(f"Hashtags reçus : {hashtags_str}")  # Afficher uniquement les hashtags
            else:
                print("Aucun hashtag reçu.")

        except json.JSONDecodeError as e:
            print(f"Erreur lors du décodage du contenu JSON : {e}")
        except Exception as e:
            print(f"Erreur inattendue : {e}")

except KeyboardInterrupt:
    print("Interruption par l'utilisateur.")

except Exception as e:
    print(f"Erreur générale : {e}")

finally:
    # Fermer les connexions
    print("Fermeture des connexions...")
    consumer.close()
    if cursor:
        cursor.close()
    if conn:
        conn.close()
    print("Connexions fermées.")
# Out:
# Topic 'mastodon_stream' already exists.
# Sending toot to Kafka: {'id': 113262416950095858, 'created_at': '2024-10-06 20:42:06+00:00', 'content': '<p>Betta Fish: My new betta baby – Iggy <a href="https://www.flakefood.com/602245/betta-fish-my-new-betta-baby-iggy/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">flakefood.com/602245/betta-fis</span><span class="invisible">h-my-new-betta-baby-iggy/</span></a> <a href="https://vive.im/tags/BettaFish" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>BettaFish</span></a></p>', 'username': 'flakefood', 'replies_count': 76, 'reblogs_count': 21, 'favourites_count': 20, 'hashtags': 'bettafish', 'language': 'en', 'url': 'https://vive.im/@flakefood/113262416782434997', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/828/056/166/original/1873f91fdca73353.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/828/056/166/small/1873f91fdca73353.jpg', 'description': 'My new betta baby - Iggy'}]}
# Sending toot to Kafka: {'id': 113262416972350708, 'created_at': '2024-10-06 20:26:56+00:00', 'content': '<p>I’m seriously praying for people in Florida</p>', 'username': 'quan.kamau', 'replies_count': 8, 'reblogs_count': 27, 'favourites_count': 48, 'hashtags': '', 'language': 'en', 'url': 'https://www.threads.net/@quan.kamau/post/DAy8rXYPP-m', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262416979020154, 'created_at': '2024-10-06 20:42:07+00:00', 'content': '<p>Boomers giving kids money before they die in ‘dysfunctional’ system <a href="https://www.byteseu.com/474508/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">byteseu.com/474508/</span><span class="invisible"></span></a> <a href="https://pubeurope.com/tags/Canada" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Canada</span></a> <a href="https://pubeurope.com/tags/CanadaPolitics" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>CanadaPolitics</span></a> <a href="https://pubeurope.com/tags/Politics" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Politics</span></a></p>', 'username': 'byteseu', 'replies_count': 18, 'reblogs_count': 3, 'favourites_count': 44, 'hashtags': 'canada, canadapolitics, politics', 'language': 'en', 'url': 'https://pubeurope.com/@byteseu/113262416823687778', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/937/449/496/original/81cf589d7de383ff.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/937/449/496/small/81cf589d7de383ff.jpg', 'description': 'Boomers giving kids money before they die in ‘dysfunctional’ system'}]}
# Sending toot to Kafka: {'id': 113262416992245000, 'created_at': '2024-10-06 20:41:30+00:00', 'content': '<p>At Packers-Rams in LA with 40,000 or so Packers fans. It just erupted on that catch.</p>', 'username': 'AndrewBrandt', 'replies_count': 79, 'reblogs_count': 96, 'favourites_count': 12, 'hashtags': '', 'language': 'en', 'url': 'https://twitter.com/AndrewBrandt/status/1843028833450262686', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417017056994, 'created_at': '2024-10-06 20:41:26+00:00', 'content': '<p>Movie tip: if you ever hurt your back so bad you need several different pain meds to be able to shuffle carefully and slowly to the kitchen of your own house: </p><p>Don’t try to watch Tenet. 🫠<br>(To be fair I mix up left and right in my normal state so this might be hard for my brain in any event)</p>', 'username': 'Patricia', 'replies_count': 69, 'reblogs_count': 83, 'favourites_count': 50, 'hashtags': '', 'language': 'en', 'url': 'https://social.vivaldi.net/@Patricia/113262414193958156', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/974/721/996/original/0107c1c2b77f0541.mp4', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/974/721/996/small/0107c1c2b77f0541.png', 'description': 'Car Chase Action GIF by Regal'}]}
# Sending toot to Kafka: {'id': 113262417033022776, 'created_at': '2024-10-06 20:40:58+00:00', 'content': '<p>Imagine if one fifth of US population was displaced from their homes because of Mexico bombing us over the actions of one of many militarized militias in US? <a href="https://twitter.com/sallyhayd/status/1842892779959071163" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">x.com/sallyhayd/stat…</span><span class="invisible"></span></a></p>', 'username': 'DavidAmoyal', 'replies_count': 28, 'reblogs_count': 33, 'favourites_count': 3, 'hashtags': '', 'language': 'en', 'url': 'https://twitter.com/DavidAmoyal/status/1843028701719769101', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/974/792/282/original/efb0e0b0561143e9.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/974/792/282/small/efb0e0b0561143e9.jpg', 'description': 'Things I have seen in the rubble of Israeli air strikes in Lebanon over the past week (a thread). 1/ https://t.co/3Jp5wrJuN6'}]}
# Sending toot to Kafka: {'id': 113262417080749254, 'created_at': '2024-10-06 20:41:31+00:00', 'content': '<p>DOT</p>', 'username': 'PardonMyTake', 'replies_count': 92, 'reblogs_count': 54, 'favourites_count': 42, 'hashtags': '', 'language': 'und', 'url': 'https://twitter.com/PardonMyTake/status/1843028840039473500', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/000/501/649/original/8833a911f675eb4e.mp4', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/000/501/649/small/8833a911f675eb4e.png', 'description': None}]}
# Sending toot to Kafka: {'id': 113262417106795192, 'created_at': '2024-10-06 20:42:10+00:00', 'content': '<p>すばらしい仕事をする唯一の方法は、自分のやっていることを好きになることだ。</p><p>おはようございます。今週も、５連勤！週末からは3連休。来週3連休明け定期通院で、実質4連休だ！さあ、今週も、元気良く笑顔で、行くよ！行くよ！</p>', 'username': 'hiro_kun55', 'replies_count': 13, 'reblogs_count': 45, 'favourites_count': 51, 'hashtags': '', 'language': 'ja', 'url': 'https://mstdn.jp/@hiro_kun55/113262417082779044', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417107399684, 'created_at': '2024-10-06 20:42:08.303000+00:00', 'content': '<a class="hashtag" href="https://milker.cafe/tag/foxywaifu" rel="nofollow noopener noreferrer" target="_blank">#FoxyWaifu</a><br><br><br>Source: <a href="https://twitter.com/Kayakove/status/1605471118864699392" rel="nofollow noopener noreferrer" target="_blank">https://twitter.com/Kayakove/status/1605471118864699392</a>', 'username': 'yaebot', 'replies_count': 92, 'reblogs_count': 67, 'favourites_count': 65, 'hashtags': 'foxywaifu', 'language': None, 'url': 'https://milker.cafe/objects/2c692777-1862-4020-ba37-b786960de458', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/017/003/994/original/9f3f9a6539625dac.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/017/003/994/small/9f3f9a6539625dac.jpg', 'description': None}]}
# Sending toot to Kafka: {'id': 113262417118822318, 'created_at': '2024-10-06 20:40:33+00:00', 'content': '<p>So nice, Hernandez strikes twice! 🚀</p><p><span class="h-card"><a href="https://twitter.com/lafc_2" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>lafc_2@twitter.com</span></a></span> jumps in front!</p>', 'username': 'MLSNEXTPRO', 'replies_count': 15, 'reblogs_count': 90, 'favourites_count': 68, 'hashtags': '', 'language': 'en', 'url': 'https://twitter.com/MLSNEXTPRO/status/1843028594768953382', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/950/036/174/original/0aa0a9d3404b8be5.mp4', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/416/950/036/174/small/0aa0a9d3404b8be5.png', 'description': None}]}
# Sending toot to Kafka: {'id': 113262417190245012, 'created_at': '2024-10-06 20:42:10+00:00', 'content': '<p><a href="https://airwaves.social/tags/VesselAlert" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>VesselAlert</span></a><br>Vessel Name: <a href="https://airwaves.social/tags/FREEDOM" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FREEDOM</span></a><br><a href="https://airwaves.social/tags/MMSI" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MMSI</span></a>: #367377380<br>Callsign: <a href="https://airwaves.social/tags/WYR2173" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WYR2173</span></a><br>Type: <a href="https://airwaves.social/tags/Passenger" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Passenger</span></a><br><a href="https://airwaves.social/tags/Flag" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Flag</span></a>: <a href="https://airwaves.social/tags/USA" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>USA</span></a><br>Msgs recvd: 2608<br>Seen on: 06-Oct-2024 16:41:59 EDT<br>Status: <a href="https://airwaves.social/tags/under_way_using_engine" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>under_way_using_engine</span></a><br>Heading: 278 deg<br>Distance: 5.9 nm<br>Signal <a href="https://airwaves.social/tags/RSSI" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span
class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FCBarcelona</span></a> <a href="https://pubeurope.com/tags/Football" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Football</span></a> <a href="https://pubeurope.com/tags/FutbolClubBarcelona" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FutbolClubBarcelona</span></a> <a href="https://pubeurope.com/tags/LaLiga" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LaLiga</span></a> <a href="https://pubeurope.com/tags/Soccer" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Soccer</span></a> <a href="https://pubeurope.com/tags/spain" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>spain</span></a> <a href="https://pubeurope.com/tags/SpanishSoccer" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SpanishSoccer</span></a></p>', 'username': 'europesays', 'replies_count': 5, 'reblogs_count': 27, 'favourites_count': 87, 'hashtags': 'f, fcbarcelona, football, FutbolClubBarcelona, laliga, soccer, spain, spanishsoccer', 'language': 'en', 'url': 'https://pubeurope.com/@europesays/113262416886679639', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/223/074/336/original/df66dcc88ede84f8.jpeg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/223/074/336/small/df66dcc88ede84f8.jpeg', 'description': 'Lewandowski makes it 1-0 with an amazing header!'}]}
# Sending toot to Kafka: {'id': 113262417243250900, 'created_at': '2024-10-06 20:42:10+00:00', 'content': '<p><a href="https://www.minenest.com/377446/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://www.</span><span class="">minenest.com/377446/</span><span class="invisible"></span></a> A tied arch bridge <a href="https://channels.im/tags/Minecraft" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Minecraft</span></a> <a href="https://channels.im/tags/MinecraftBuilds" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>MinecraftBuilds</span></a></p>', 'username': 'minenest', 'replies_count': 2, 'reblogs_count': 71, 'favourites_count': 83, 'hashtags': 'minecraft, minecraftbuilds', 'language': 'en', 'url': 'https://channels.im/@minenest/113262417051686915', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/090/107/407/original/3e94213b7dcbbf28.png', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/090/107/407/small/3e94213b7dcbbf28.png', 'description': 'A tied arch bridge'}]}
# Sending toot to Kafka: {'id': 113262417272069779, 'created_at': '2024-10-06 20:42:13+00:00', 'content': '<p>Верес заповнить паузу в чемпіонаті спарингом з одним із лідерів УПЛ<br><a href="https://sport.ua/uk/news/708264-veres-zapovnit-pauzu-v-chempionati-sparingom-z-odnim-iz-lideriv-upl" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">sport.ua/uk/news/708264-veres-</span><span class="invisible">zapovnit-pauzu-v-chempionati-sparingom-z-odnim-iz-lideriv-upl</span></a></p><p><a href="https://social.kyiv.dcomm.net.ua/tags/sport" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>sport</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/news" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>news</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/ukrainian" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ukrainian</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D1%81%D0%BF%D0%BE%D1%80%D1%82" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>спорт</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D0%BD%D0%BE%D0%B2%D0%B8%D0%BD%D0%B8" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>новини</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D1%83%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%81%D1%8C%D0%BA%D0%BE%D1%8E" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>українською</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D1%84%D1%83%D1%82%D0%B1%D0%BE%D0%BB" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>футбол</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D1%83%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B0" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>україна</span></a> <a href="https://social.kyiv.dcomm.net.ua/tags/%D0%BF%D1%80%D0%B5%D0%BC" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>прем</span></a>\'єрліга</p>', 'username': 'sport_ua_feed', 'replies_count': 58, 'reblogs_count': 86, 'favourites_count': 52, 'hashtags': 'sport, news, ukrainian, спорт, новини, українською, футбол, україна, прем', 'language': 'en', 'url': 'https://social.kyiv.dcomm.net.ua/@sport_ua_feed/113262417216398741', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417317848287, 'created_at': '2024-10-06 20:42:13+00:00', 'content': '<p>Ферран Торрес пропустить місяць і не зіграє з Реалом<br><a href="https://football.ua/spain/540398-ferran-torres-propustit-misjac-i-ne-zigraje-z-realom.html" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">football.ua/spain/540398-ferra</span><span class="invisible">n-torres-propustit-misjac-i-ne-zigraje-z-realom.html</span></a></p><p><a href="https://social.kyiv.dcomm.net.ua/tags/football" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span
rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">stern.de/gesellschaft/trennung</span><span class="invisible">sgeschichte--nach-einer-eiskalten-hochzeit-war-es-sofort-aus-33950608.html?utm_campaign=alle&amp;utm_medium=rss-feed&amp;utm_source=standard</span></a></p><p><a href="https://ma.suldomi.net/tags/stern" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>stern</span></a> <a href="https://ma.suldomi.net/tags/news" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>news</span></a></p>', 'username': 'bot', 'replies_count': 78, 'reblogs_count': 92, 'favourites_count': 65, 'hashtags': 'stern, news', 'language': 'de', 'url': 'https://ma.suldomi.net/@bot/113262417553768546', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417647101220, 'created_at': '2024-10-06 20:42:18+00:00', 'content': '<p>My traditional birthday banana cake from <span class="h-card" translate="no"><a href="https://mastodon.social/@DoorbellQueen" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>DoorbellQueen</span></a></span> . Thanks, Sweetie!</p><p><a href="https://mastodon.gamedev.place/tags/EatingWell" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>EatingWell</span></a></p>', 'username': 'Professor_Stevens', 'replies_count': 39, 'reblogs_count': 70, 'favourites_count': 15, 'hashtags': 'eatingwell', 'language': 'en', 'url': 'https://mastodon.gamedev.place/@Professor_Stevens/113262417562847908', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/585/984/219/original/7c9839da71519763.png', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/585/984/219/small/7c9839da71519763.png', 'description': 'Slice of cake on a white plate with chocolate ice cream. Blue teacup full of tea. Blue and white placemat.'}]}
# Sending toot to Kafka: {'id': 113262417657714337, 'created_at': '2024-10-06 20:42:19.752000+00:00', 'content': '<p>Estrasburgo – Lens: mais um empate para o Sang et Or <a href="https://mastodon.social/tags/%C3%9AltimasNot%C3%ADcias" class="mention hashtag" rel="tag">#<span>ÚltimasNotícias</span></a> <a href="https://mastodon.social/tags/Fran%C3%A7a" class="mention hashtag" rel="tag">#<span>França</span></a></p><p>Hot News Privado de onze jogadores, Will Still teve de rever a sua cópia para compor um “onze” que terá de encontrar o caminho da vitória frente ao Estrasburgo. &gt; O que você precisa saber Na defesa central, Malang Sarr é titular em Estrasburgo. Angelo Fulgini joga em dez, responsável por alimentar a dupla M&#39;Bala Nzola – Wesley Saïd, tal como frente ao Nice (0-0).</p><p><a href="https://hotnews.pt/news-fr/estrasburgo-lens-mais-um-empate-para-o-sang-et-or-ultimasnoticias-franca/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">hotnews.pt/news-fr/estrasburgo</span><span class="invisible">-lens-mais-um-empate-para-o-sang-et-or-ultimasnoticias-franca/</span></a></p>', 'username': 'hotnews_pt', 'replies_count': 20, 'reblogs_count': 93, 'favourites_count': 46, 'hashtags': 'ultimasnoticias, franca', 'language': 'en', 'url': 'https://mastodon.social/@hotnews_pt/113262417657714337', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417633218321, 'created_at': '2024-10-06 20:42:18+00:00', 'content': '<p>Unity peeps, any decent Constructive Solid Geometry (CSG) solutions for booleans in Unity? Especially interested in subtractive boolean functionality.</p>', 'username': 'mrt3d', 'replies_count': 2, 'reblogs_count': 10, 'favourites_count': 91, 'hashtags': '', 'language': 'en', 'url': 'https://mastodon.gamedev.place/@mrt3d/113262417608467691', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417670957277, 'created_at': '2024-10-06 20:42:14+00:00', 'content': '<p>Throwback episode of <span class="h-card"><a href="https://mas.to/@grantbarrett" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>grantbarrett</span></a></span> and Martha: Yak Shaving (episode #1548) – A Way with Words, a fun radio show and podcast about <a href="https://mastodon.sdf.org/tags/language" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>language</span></a></p><p><a href="https://mastodon.sdf.org/tags/YakShaving" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>YakShaving</span></a> <a href="https://mastodon.sdf.org/tags/etymology" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>etymology</span></a> <br><a href="https://waywordradio.org/yak-shaving/" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="">waywordradio.org/yak-shaving/</span><span class="invisible"></span></a></p>', 'username': 'cs', 'replies_count': 99, 'reblogs_count': 99, 'favourites_count': 42, 'hashtags': 'language, yakshaving, etymology', 'language': 'en', 'url': 'https://mastodon.sdf.org/@cs/113262417324862034', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417689334853, 'created_at': '2024-10-06 20:41:45+00:00', 'content': "<p>josh needed to tell them ' this is stupid ' too . he has enough power to tell them ' we should the run ball ' here. cant just blame brady . mcdermott has a head set on with mic for reason . he knows what plays are being called . its on him not brady</p>", 'username': 'sportsrage', 'replies_count': 37, 'reblogs_count': 52, 'favourites_count': 75, 'hashtags': '', 'language': 'en', 'url': 'https://twitter.com/sportsrage/status/1843028896171843801', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417688441655, 'created_at': '2024-10-06 20:42:10+00:00', 'content': '<p>The Broncos have 2nd-and-38...</p>', 'username': 'ZacStevensDNVR', 'replies_count': 58, 'reblogs_count': 48, 'favourites_count': 24, 'hashtags': '', 'language': 'en', 'url': 'https://twitter.com/ZacStevensDNVR/status/1843029003168575933', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417688527215, 'created_at': '2024-10-06 20:42:18+00:00', 'content': '<p>Der Nachbericht von der Vernissage im Hallenberger Kump</p><p>Cosima von Borsody: „Mir war es immer wichtig, positive und heitere Bilder zu gestalten…“</p><p><a href="https://ruhr.social/tags/Hallenberg" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Hallenberg</span></a> <a href="https://ruhr.social/tags/Kump" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Kump</span></a> <a href="https://ruhr.social/tags/Vernissage" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Vernissage</span></a> <a href="https://ruhr.social/tags/CosimaVonBorsody" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>CosimaVonBorsody</span></a></p><p><a href="https://www.schiebener.net/wordpress/vernissage-cosima-von-borsody-im-hallenberger-kump/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">schiebener.net/wordpress/verni</span><span class="invisible">ssage-cosima-von-borsody-im-hallenberger-kump/</span></a></p>', 'username': 'hskzoom', 'replies_count': 65, 'reblogs_count': 54, 'favourites_count': 53, 'hashtags': 'hallenberg, kump, vernissage, cosimavonborsody', 'language': 'de', 'url': 'https://ruhr.social/@hskzoom/113262417606072545', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/648/306/003/original/0fd087ebb1bd15b2.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/417/648/306/003/small/0fd087ebb1bd15b2.jpg', 'description': 'Braun-Weiß gestreifte Katze schaut den Betrachter zwischen roten Blüten liegend an. Im Hintergrund sieben Baumstämme. Insgesamt herrscht eien rot-braune Farbstimmung vor.'}]}
# Sending toot to Kafka: {'id': 113262417789003051, 'created_at': '2024-10-06 20:42:20+00:00', 'content': '<p>2024 todo mundo falando de política sem uma unidade de cw será q não aprendemos nada mesmo</p>', 'username': 'miugnutos', 'replies_count': 74, 'reblogs_count': 92, 'favourites_count': 45, 'hashtags': '', 'language': 'pt', 'url': 'https://bolha.one/@miugnutos/113262417689574380', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417858465235, 'created_at': '2024-10-06 20:42:21+00:00', 'content': "<p>regardez Renegade Nell c'est une meuf badass qui tatanne des connards au 18eme siècle</p>", 'username': 'toniours', 'replies_count': 61, 'reblogs_count': 9, 'favourites_count': 99, 'hashtags': '', 'language': 'fr', 'url': 'https://tooter.social/@toniours/113262417779874930', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417923763569, 'created_at': '2024-10-06 20:42:23.823000+00:00', 'content': '<p>Highlights Parte 03 del RadioShow semanal <span class="h-card" translate="no"><a href="https://mastodon.social/@interfusounds" class="u-url mention">@<span>interfusounds</span></a></span> Episodio 732 presentado por <span class="h-card" translate="no"><a href="https://mastodon.social/@javierperezdj" class="u-url mention">@<span>javierperezdj</span></a></span><br />Puedes escuchar el <a href="https://mastodon.social/tags/Top70" class="mention hashtag" rel="tag">#<span>Top70</span></a> completo de este Radio Show del <a href="https://mastodon.social/tags/Trance" class="mention hashtag" rel="tag">#<span>Trance</span></a> con cinco horas y media continuas de los más nuevos y mejores lanzamientos de la semana en el <a href="https://mastodon.social/tags/trance" class="mention hashtag" rel="tag">#<span>trance</span></a> y además puedes descargarlo completamente gratis aquí: <a href="https://www.house-mixes.com/profile/javierperezdj/javier-perez-interfusounds-episode-732-september-22-2024" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">house-mixes.com/profile/javier</span><span class="invisible">perezdj/javier-perez-interfusounds-episode-732-september-22-2024</span></a></p><p>síguenos  en nuestro canal: <a href="https://whatsapp.com/channel/0029Va4x9gBGE56dIP5zVG3v" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">whatsapp.com/channel/0029Va4x9</span><span class="invisible">gBGE56dIP5zVG3v</span></a></p><p>Trance, Vocal Trance, Vocal Progressive Trance, Tech Trance, Uplifting Trance, Hard Trance,</p>', 'username': 'interfusounds', 'replies_count': 56, 'reblogs_count': 99, 'favourites_count': 18, 'hashtags': 'top70, trance', 'language': 'es', 'url': 'https://mastodon.social/@interfusounds/113262417923763569', 'media_attachments': [{'url': 'https://files.mastodon.social/media_attachments/files/113/262/416/947/606/961/original/28e2ac4f70d73617.mp4', 'preview_url': 'https://files.mastodon.social/media_attachments/files/113/262/416/947/606/961/small/28e2ac4f70d73617.png', 'description': None}]}
# Sending toot to Kafka: {'id': 113262417963470692, 'created_at': '2024-10-06 20:27:13+00:00', 'content': '<p>Hard to tell from the broadcast angle, but it looked like the Packers dialed up Yankee for Dontayvion Wicks on the opening play. NFLThreads</p>', 'username': 'by_jbh', 'replies_count': 22, 'reblogs_count': 65, 'favourites_count': 11, 'hashtags': '', 'language': 'en', 'url': 'https://www.threads.net/@by_jbh/post/DAy8thsTmu6', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262417978686062, 'created_at': '2024-10-06 20:42:21+00:00', 'content': '<p>:avis: <a href="https://mikrobloggen.no/tags/Nyheter" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Nyheter</span></a> <a href="https://mikrobloggen.no/tags/Avisrunden" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Avisrunden</span></a>  </p><p>Løfter han hodet, treffer kulen ham. Yoni Diller måtte likevel fortelle vennen noe livsviktig. </p><p>Kilde: <a href="https://mikrobloggen.no/tags/A" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>A</span></a>-magasinet </p><p>Lenke til sak:  <a href="https://www.aftenposten.no/amagasinet/i/pPMBk6/7-oktober-overlever-jeg-lurer-ofte-paa-om-jeg-burde-ha-gjort-mer" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">aftenposten.no/amagasinet/i/pP</span><span class="invisible">MBk6/7-oktober-overlever-jeg-lurer-ofte-paa-om-jeg-burde-ha-gjort-mer</span></a></p>', 'username': 'nyheter', 'replies_count': 43, 'reblogs_count': 65, 'favourites_count': 21, 'hashtags': 'nyheter, avisrunden, a', 'language': 'en', 'url': 'https://mikrobloggen.no/@nyheter/113262417757041030', 'media_attachments': []}
# ...
# Sending toot to Kafka: {'id': 113262418637885518, 'created_at': '2024-10-06 20:42:31.451000+00:00', 'content': '<p>they\'re good parents too <a href="https://ebiverse.social/tags/lizard" rel="nofollow noopener noreferrer" target="_blank">#lizard</a></p>', 'username': 'anemone', 'replies_count': 57, 'reblogs_count': 50, 'favourites_count': 18, 'hashtags': 'lizard', 'language': None, 'url': 'https://ebiverse.social/notes/9z1m5w9nvx', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/475/267/184/original/422c60482620ee50.png', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/475/267/184/small/422c60482620ee50.png', 'description': None}]}
# Sending toot to Kafka: {'id': 113262418640832675, 'created_at': '2024-10-06 20:42:34.752000+00:00', 'content': '<p>Marçal espera até o último minuto para votar, vai à urna descalço e diz que é ‘vítima do sistema’</p><p>O ex-coach chegou ao colégio eleitoral onde vota, em Moema, na Zona Sul da capital, pouco depois das 16h deste domingo 6</p><p><a href="https://www.cartacapital.com.br/cartaexpressa/marcal-espera-ate-o-ultimo-minuto-para-votar-vai-a-urna-descalco-e-diz-que-e-vitima-do-sistema/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">cartacapital.com.br/cartaexpre</span><span class="invisible">ssa/marcal-espera-ate-o-ultimo-minuto-para-votar-vai-a-urna-descalco-e-diz-que-e-vitima-do-sistema/</span></a></p>', 'username': 'noticiasbrasil', 'replies_count': 96, 'reblogs_count': 75, 'favourites_count': 85, 'hashtags': '', 'language': 'pt', 'url': 'https://mastodon.social/@noticiasbrasil/113262418640832675', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418684315292, 'created_at': '2024-10-06 20:42:20+00:00', 'content': '<p>📰 Una imagen <a href="https://tkz.one/tags/random" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>random</span></a> <a href="https://tkz.one/tags/randomImageGame" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>randomImageGame</span></a> <a href="https://tkz.one/tags/randomPic" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>randomPic</span></a> <a href="https://tkz.one/tags/imagenRandom" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>imagenRandom</span></a> <a href="https://tkz.one/tags/videogames" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>videogames</span></a> <a href="https://tkz.one/tags/ValkyriaRevolution" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ValkyriaRevolution</span></a> - Valkyria Revolution</p>', 'username': 'Skeithautomatic', 'replies_count': 51, 'reblogs_count': 11, 'favourites_count': 5, 'hashtags': 'random, randomimagegame, randompic, imagenrandom, videogames, ValkyriaRevolution', 'language': 'es', 'url': 'https://tkz.one/@Skeithautomatic/113262417729153679', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/639/767/783/original/8e57f20459c2b5cc.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/639/767/783/small/8e57f20459c2b5cc.jpg', 'description': '📰 Una imagen #random #randomImageGame #randomPic #imagenRandom #videogames #ValkyriaRevolution - Valkyria Revolution'}]}
# Sending toot to Kafka: {'id': 113262418697404079, 'created_at': '2024-10-06 20:42:33+00:00', 'content': '<p>一周五练是为什么 还不是为了装逼拍照发朋友圈 可是我不敢发 因为我真的认识好多练的比我好太多的男男女女了</p>', 'username': 'misszaogao', 'replies_count': 33, 'reblogs_count': 92, 'favourites_count': 93, 'hashtags': '', 'language': 'zh-CN', 'url': 'https://nofan.xyz/@misszaogao/113262418576149760', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/646/415/881/original/f70a9c97336e6dc0.jpeg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/646/415/881/small/f70a9c97336e6dc0.jpeg', 'description': None}]}
# Sending toot to Kafka: {'id': 113262418703867040, 'created_at': '2024-10-06 20:27:24+00:00', 'content': '<p>De volta à rotina! 👊🏻👊🏻 Semana que vem aí, bora encarar com tudo!  #Voltei #Segunda #SemanaComeçou #BoaSemana #DeBoa"</p>', 'username': 'paulagottlieb', 'replies_count': 19, 'reblogs_count': 33, 'favourites_count': 10, 'hashtags': '', 'language': 'pt', 'url': 'https://www.threads.net/@paulagottlieb/post/DAy8uv9yJC4', 'media_attachments': [{'url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/673/251/178/original/a66c63835b9dbd83.jpg', 'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/113/262/418/673/251/178/small/a66c63835b9dbd83.jpg', 'description': 'Photo by Paula Gottlieb on October 06, 2024. May be an image of 1 person, biceps, smiling, activewear, sportswear and text.'}]}
# Sending toot to Kafka: {'id': 113262418706017401, 'created_at': '2024-10-06 20:42:35.742000+00:00', 'content': '<p>I wish there was no such thing as private email</p>', 'username': 'Lautschrift', 'replies_count': 22, 'reblogs_count': 75, 'favourites_count': 15, 'hashtags': '', 'language': 'de', 'url': 'https://mastodon.social/@Lautschrift/113262418706017401', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418722411367, 'created_at': '2024-10-06 20:42:33+00:00', 'content': '<p>Nach dem Suitwalk gestern hat noch kultureller Austausch stattgefunden.<br>Die Amerikaner versuchten uns Blackjack und Pokern beizubringen während wir Goaßmaß und Rüscherl mischten.<br>Es war ein schöner Tag mit coolen Leuten</p>', 'username': 'Eichi', 'replies_count': 6, 'reblogs_count': 10, 'favourites_count': 34, 'hashtags': '', 'language': 'de', 'url': 'https://mastodon.bierschutzpartei.de/@Eichi/113262418526725079', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418748081683, 'created_at': '2024-10-06 20:42:35.480000+00:00', 'content': '<p><span>この夢の続きを見て、始業式と入学式で演奏しなくてはならないのに、起きた時点で入学式の 30 分前で「あっもう間に合わんな … 」とすべてを諦めて欠席連絡をしようとしていた。しかし持っているのはガラケーで、上手く入力できないうえに、パートリーダーのメールアドレスを知らないことに気付いて詰んでいた。</span></p>', 'username': 'ddquino', 'replies_count': 83, 'reblogs_count': 47, 'favourites_count': 37, 'hashtags': '', 'language': 'ja', 'url': 'https://ddoskey.com/notes/9z1m5zdkutzd7swm', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418902369321, 'created_at': '2024-10-06 20:42:37+00:00', 'content': '<p>Πάει η μεγάλη ανατροπή σύντροφοι</p>', 'username': 'electric_knife', 'replies_count': 56, 'reblogs_count': 59, 'favourites_count': 62, 'hashtags': '', 'language': 'en', 'url': 'https://kafeneio.social/@electric_knife/113262418834146035', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418918737902, 'created_at': '2024-10-06 20:42:38.991000+00:00', 'content': '<p>Neural Longevity: Study Explores How Neurons Live So Long – Neuroscience\xa0News</p><p>Summary: Scientists are investigating the extraordinary longevity of neurons, which can survive for over 90 years, in a new research project. This study aims to uncover the genetic and molecular mechanisms that enable neurons to live so long. The findings could not only improve understanding of neural aging but also lead to treatments for neurodegenerative diseases like Parkinson’s and ALS.…</p><p><a href="https://pressnewsagency.org/neural-longevity-study-explores-how-neurons-live-so-long-neuroscience-news/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">pressnewsagency.org/neural-lon</span><span class="invisible">gevity-study-explores-how-neurons-live-so-long-neuroscience-news/</span></a></p>', 'username': 'PressNewsAgency', 'replies_count': 27, 'reblogs_count': 76, 'favourites_count': 69, 'hashtags': '', 'language': 'en', 'url': 'https://mastodon.social/@PressNewsAgency/113262418918737902', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262418923125045, 'created_at': '2024-10-06 20:42:39.059000+00:00', 'content': '<p>2:42p Traveling After Dark by Aaron Lee Tasjan from Self Doubt</p>', 'username': 'the_colorado_sound_playlist', 'replies_count': 99, 'reblogs_count': 94, 'favourites_count': 78, 'hashtags': '', 'language': 'en', 'url': 'https://mastodon.social/@the_colorado_sound_playlist/113262418923125045', 'media_attachments': [{'url': 'https://files.mastodon.social/media_attachments/files/113/262/418/887/474/403/original/a9024134e1e9faa1.jpg', 'preview_url': 'https://files.mastodon.social/media_attachments/files/113/262/418/887/474/403/small/a9024134e1e9faa1.jpg', 'description': "An image of the cover of the record album 'Self Doubt' by Aaron Lee Tasjan"}]}
# Sending toot to Kafka: {'id': 113262418997893192, 'created_at': '2024-10-06 20:27:28+00:00', 'content': '<p>Eu to realmente surpreso com a quantidade de idiota por metro quadrado que tem na cidade de São Paulo…<br><br>RE: <a href="https://www.threads.net/@metropoles/post/DAy79VaJMXQ" rel="nofollow noopener noreferrer" target="_blank">https://www.threads.net/@metropoles/post/DAy79VaJMXQ</a></p>', 'username': 'vlaad', 'replies_count': 9, 'reblogs_count': 37, 'favourites_count': 7, 'hashtags': '', 'language': 'pt', 'url': 'https://www.threads.net/@vlaad/post/DAy8vPfBKB8', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262419004235538, 'created_at': '2024-10-06 20:42:40.297000+00:00', 'content': '<p>ایک عام غذائی جز، جو آپ کے غصیلے رویہ کو کم کرسکتا\xa0ہے</p><p>ایک عام غذائی جز، جو آپ کے غصیلے رویہ کو کم کرسکتا ہے غلط بات پر غصہ آنا فطری عمل ہے تاہم کچھ لوگوں میں یہ رویہ اتنی زیادہ ہوتا پے کہ وہ معمولی سی بات بھی جارحیت پر اتر آتے ہیں، تاہم ایک عام غذائی جز اس رویے کو 28 فیصد تک کم کرسکتا ہے۔ پنسلوانیا یونیورسٹی کے محققین نے اومیگا 3 کے جارحیت پر اثرات کے بارے میں ماضی میں کیے گئے 29 رینڈمائزڈ کنٹرولڈ ٹرائلز کا جائزہ لیا جن میں کل 3,918 شرکاء شامل تھے۔</p><p><a href="https://urdupress.co.uk/%d8%a7%db%8c%da%a9-%d8%b9%d8%a7%d9%85-%d8%ba%d8%b0%d8%a7%d8%a6%db%8c-%d8%ac%d8%b2%d8%8c-%d8%ac%d9%88-%d8%a2%d9%be-%da%a9%db%92-%d8%ba%d8%b5%db%8c%d9%84%db%92-%d8%b1%d9%88%db%8c%db%81-%da%a9%d9%88/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">urdupress.co.uk/%d8%a7%db%8c%d</span><span class="invisible">a%a9-%d8%b9%d8%a7%d9%85-%d8%ba%d8%b0%d8%a7%d8%a6%db%8c-%d8%ac%d8%b2%d8%8c-%d8%ac%d9%88-%d8%a2%d9%be-%da%a9%db%92-%d8%ba%d8%b5%db%8c%d9%84%db%92-%d8%b1%d9%88%db%8c%db%81-%da%a9%d9%88/</span></a></p>', 'username': 'urdupress', 'replies_count': 3, 'reblogs_count': 2, 'favourites_count': 3, 'hashtags': '', 'language': 'en', 'url': 'https://mastodon.social/@urdupress/113262419004235538', 'media_attachments': []}
# Sending toot to Kafka: {'id': 113262419013886396, 'created_at': '2024-10-06 20:42:33+00:00', 'content': '<p><a href="https://janerationx.social/tags/Vanderbilt" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Vanderbilt</span></a> beat the #1 team in the country and didn\'t even make the bottom rung on the AP poll. That\'s just wrong. 🙄</p>', 'username': 'j', 'replies_count': 38, 'reblogs_count': 99, 'favourites_count': 70, 'hashtags': 'vanderbilt', 'language': 'en', 'url': 'https://janerationx.social/@j/113262418584813186', 'media_attachments': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 102
#      99 listener = MyListener(producer, topic_name, keywords)
#     101 # Streamer les toots publics en temps réel
# --> 102 mastodon.stream_public(listener)
#
# File /opt/conda/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/conda/lib/python3.11/site-packages/mastodon/utility.py:49, in api_version.<locals>.api_min_version_decorator.<locals>.wrapper(function, self, *args, **kwargs)
#      47     elif major == self.mastodon_major and minor == self.mastodon_minor and patch > self.mastodon_patch:
#      48         raise MastodonVersionError(f"Version check failed (Need version {version}, patch is {self.mastodon_patch})")
# ---> 49 return function(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/mastodon/streaming_endpoints.py:38, in Mastodon.stream_public(self, listener, run_async, timeout, reconnect_async, reconnect_async_wait_sec, local, remote)
#      36         raise MastodonIllegalArgumentError("Cannot pass both local and remote - use either one or the other.")
#      37     base += '/remote'
# ---> 38 return self.__stream(base, listener, run_async=run_async, timeout=timeout, reconnect_async=reconnect_async, reconnect_async_wait_sec=reconnect_async_wait_sec)
#
# File /opt/conda/lib/python3.11/site-packages/mastodon/internals.py:540, in Mastodon.__stream(self, endpoint, listener, params, run_async, timeout, reconnect_async, reconnect_async_wait_sec)
#     538 connection = connect_func()
#     539 with closing(connection) as r:
# --> 540     listener.handle_stream(r)
#
# File /opt/conda/lib/python3.11/site-packages/mastodon/streaming.py:109, in StreamListener.handle_stream(self, response)
#     107 line_buffer = bytearray()
#     108 try:
# --> 109     for chunk in response.iter_content(chunk_size=1):
#     110         if chunk:
#     111             for chunk_part in chunk:
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/response.py:933, in HTTPResponse.stream(self, amt, decode_content)
#     917 """
#     918 A generator wrapper for the read() method. A call will block until
#     919 ``amt`` bytes have been read from the connection or until the
#    (...)
#     930     'content-encoding' header.
#     931 """
#     932 if self.chunked and self.supports_chunked_reads():
# --> 933     yield from self.read_chunked(amt, decode_content=decode_content)
#     934 else:
#     935     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/response.py:1073, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1070     return None
#    1072 while True:
# -> 1073     self._update_chunk_length()
#    1074     if self.chunk_left == 0:
#    1075         break
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/response.py:1001, in HTTPResponse._update_chunk_length(self)
#     999 if self.chunk_left is not None:
#    1000     return None
# -> 1001 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1002 line = line.split(b";", 1)[0]
#    1003 try:
#
# File /opt/conda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
